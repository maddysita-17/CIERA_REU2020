# %%
# %matplotlib notebook

import obspy
from obspy.clients.fdsn import Client
from obspy import UTCDateTime
from obspy import read_events
import matplotlib.pyplot as plt
client = Client("IRIS")
from matplotlib.dates import DateFormatter
import matplotlib.ticker as ticker
import numpy as np
import math
import pandas as pd

catalog = read_events('http://ds.iris.edu/files/insight/2020-01-01/events_extended_preferredorigin_2020-01-01.xml')

# %%
print(catalog)
# Out:
# 383 Event(s) in Catalog:
# 2019-12-31T17:30:00.000000Z |  +4.502, +135.623 | 1.6 M2.4 | manual
# 2019-12-30T18:22:51.000000Z |  +4.502, +135.623 | 1.6 M2.4 | manual
# ...
# 2019-03-14T20:59:38.000000Z |  +4.502, +135.623 | 3.3 MFB | manual
# 2019-01-13T05:53:29.000000Z |  +4.502, +135.623 | 1.9 MFB | manual
# To see all events call 'print(CatalogObject.__str__(print_all=True))'

# %%
#most of the 2.4Hz events fall below a 2.0MFB Magnitude -> can filter the read_events func
catalog2 = catalog.filter('magnitude < 2.0')
print(catalog2)
# Out:
# 333 Event(s) in Catalog:
# 2019-12-31T17:30:00.000000Z |  +4.502, +135.623 | 1.6 M2.4 | manual
# 2019-12-30T18:22:51.000000Z |  +4.502, +135.623 | 1.6 M2.4 | manual
# ...
# 2019-03-26T06:20:00.000000Z |  +4.502, +135.623 | 1.3 M2.4 | manual
# 2019-01-13T05:53:29.000000Z |  +4.502, +135.623 | 1.9 MFB | manual
# To see all events call 'print(CatalogObject.__str__(print_all=True))'

# %%
#prints out UTCDateTime objects
for event in catalog:
    print(event.origins[0].time)
    
print(type(event.origins[0].time))
# Out:
# 2019-12-31T17:30:00.000000Z
# 2019-12-30T18:22:51.000000Z
# 2019-12-30T15:46:43.000000Z
# 2019-12-29T14:36:06.000000Z
# 2019-12-28T18:02:08.000000Z
# 2019-12-28T14:52:30.000000Z
# 2019-12-27T15:06:37.000000Z
# 2019-12-27T13:50:37.000000Z
# 2019-12-27T12:37:42.000000Z
# 2019-12-26T16:38:20.000000Z
# 2019-12-26T14:45:04.000000Z
# 2019-12-26T13:04:26.000000Z
# 2019-12-26T11:49:57.000000Z
# 2019-12-25T15:43:18.000000Z
# 2019-12-25T15:22:37.000000Z
# 2019-12-25T14:32:24.000000Z
# 2019-12-24T14:31:50.000000Z
# 2019-12-23T13:49:15.000000Z
# 2019-12-23T13:30:47.000000Z
# 2019-12-23T11:45:35.000000Z
# 2019-12-23T11:06:00.000000Z
# 2019-12-23T10:52:43.000000Z
# 2019-12-23T09:59:27.000000Z
# 2019-12-22T15:21:55.000000Z
# 2019-12-21T13:43:26.000000Z
# 2019-12-21T12:22:36.000000Z
# 2019-12-20T13:08:30.000000Z
# 2019-12-20T07:53:37.000000Z
# 2019-12-19T11:57:20.000000Z
# 2019-12-19T10:51:09.000000Z
# 2019-12-19T10:01:16.000000Z
# 2019-12-18T11:53:30.000000Z
# 2019-12-17T16:32:22.000000Z
# 2019-12-17T10:13:55.000000Z
# 2019-12-16T11:45:12.000000Z
# 2019-12-16T10:02:02.000000Z
# 2019-12-15T10:18:13.000000Z
# 2019-12-15T07:07:31.000000Z
# 2019-12-14T07:31:54.000000Z
# 2019-12-13T08:23:51.000000Z
# 2019-12-13T06:39:08.000000Z
# 2019-12-12T03:17:29.000000Z
# 2019-12-11T08:00:23.000000Z
# 2019-12-11T03:53:02.000000Z
# 2019-12-11T01:50:49.000000Z
# 2019-12-10T07:09:03.000000Z
# 2019-12-09T04:42:09.000000Z
# 2019-12-09T03:43:00.000000Z
# 2019-12-09T01:42:46.000000Z
# 2019-12-09T00:31:03.000000Z
# 2019-12-08T05:36:24.000000Z
# 2019-12-08T03:32:43.000000Z
# 2019-12-08T02:33:48.000000Z
# 2019-12-08T01:45:15.000000Z
# 2019-12-08T00:24:38.000000Z
# 2019-12-07T05:59:42.000000Z
# 2019-12-07T05:28:08.000000Z
# 2019-12-07T00:49:35.000000Z
# 2019-12-06T02:50:12.000000Z
# 2019-12-05T01:33:11.000000Z
# 2019-12-05T00:48:20.000000Z
# 2019-12-05T00:08:18.000000Z
# 2019-12-04T22:53:48.000000Z
# 2019-12-04T01:13:36.000000Z
# 2019-12-03T23:30:53.000000Z
# 2019-12-03T22:06:04.000000Z
# 2019-12-03T00:40:48.000000Z
# 2019-12-02T23:08:33.000000Z
# 2019-12-02T03:22:00.000000Z
# 2019-12-01T23:50:56.000000Z
# 2019-12-01T20:04:41.000000Z
# 2019-11-30T21:07:10.000000Z
# 2019-11-30T00:45:44.000000Z
# 2019-11-29T22:54:01.000000Z
# 2019-11-29T21:42:52.000000Z
# 2019-11-29T00:18:04.000000Z
# 2019-11-28T19:22:00.000000Z
# 2019-11-26T16:42:50.000000Z
# 2019-11-25T01:21:22.000000Z
# 2019-11-24T21:57:15.000000Z
# 2019-11-24T19:58:54.000000Z
# 2019-11-24T18:49:01.000000Z
# 2019-11-24T16:35:14.000000Z
# 2019-11-24T15:04:34.000000Z
# 2019-11-24T02:21:39.000000Z
# 2019-11-23T19:27:22.000000Z
# 2019-11-23T18:14:20.000000Z
# 2019-11-22T17:40:33.000000Z
# 2019-11-21T15:58:29.000000Z
# 2019-11-20T17:09:14.000000Z
# 2019-11-19T22:51:20.000000Z
# 2019-11-19T17:44:21.000000Z
# 2019-11-19T15:45:40.000000Z
# 2019-11-19T14:48:09.000000Z
# 2019-11-19T14:00:50.000000Z
# 2019-11-18T14:47:32.000000Z
# 2019-11-17T15:25:02.000000Z
# 2019-11-17T15:11:22.000000Z
# 2019-11-17T14:25:19.000000Z
# 2019-11-17T12:25:32.000000Z
# 2019-11-16T15:35:16.000000Z
# 2019-11-16T14:42:08.000000Z
# 2019-11-16T14:00:22.000000Z
# 2019-11-16T12:03:41.000000Z
# 2019-11-15T10:01:17.000000Z
# 2019-11-15T09:46:28.000000Z
# 2019-11-14T11:57:48.000000Z
# 2019-11-14T11:35:08.000000Z
# 2019-11-13T12:56:18.000000Z
# 2019-11-12T12:19:01.000000Z
# 2019-11-11T11:06:07.000000Z
# 2019-11-11T09:49:03.000000Z
# 2019-11-10T11:07:18.000000Z
# 2019-11-10T10:01:27.000000Z
# 2019-11-10T09:15:59.000000Z
# 2019-11-10T08:04:18.000000Z
# 2019-11-10T07:19:17.000000Z
# 2019-11-10T06:24:57.000000Z
# 2019-11-09T07:19:44.000000Z
# 2019-11-08T12:07:32.000000Z
# 2019-11-08T11:22:06.000000Z
# 2019-11-06T09:00:10.000000Z
# 2019-11-06T07:25:05.000000Z
# 2019-11-06T04:47:23.000000Z
# 2019-11-05T06:08:35.000000Z
# 2019-11-05T05:21:36.000000Z
# 2019-11-05T04:00:35.000000Z
# 2019-11-04T05:36:58.000000Z
# 2019-11-03T02:00:31.000000Z
# 2019-11-02T06:52:11.000000Z
# 2019-11-01T08:31:01.000000Z
# 2019-10-31T10:05:39.000000Z
# 2019-10-31T04:31:02.000000Z
# 2019-10-31T00:42:58.000000Z
# 2019-10-29T04:20:35.000000Z
# 2019-10-29T03:55:01.000000Z
# 2019-10-29T01:28:20.000000Z
# 2019-10-28T23:22:24.000000Z
# 2019-10-27T03:52:00.000000Z
# 2019-10-27T01:58:28.000000Z
# 2019-10-27T01:16:25.000000Z
# 2019-10-26T06:30:10.000000Z
# 2019-10-26T04:38:25.000000Z
# 2019-10-26T02:14:41.000000Z
# 2019-10-25T21:16:19.000000Z
# 2019-10-25T08:06:39.000000Z
# 2019-10-25T06:17:56.000000Z
# 2019-10-25T05:16:58.000000Z
# 2019-10-25T00:53:41.000000Z
# 2019-10-25T00:20:29.000000Z
# 2019-10-25T00:02:38.000000Z
# 2019-10-24T21:08:41.000000Z
# 2019-10-23T02:02:10.000000Z
# 2019-10-22T19:35:59.000000Z
# 2019-10-21T20:09:07.000000Z
# 2019-10-21T04:53:12.000000Z
# 2019-10-20T17:40:35.000000Z
# 2019-10-20T03:24:42.000000Z
# 2019-10-19T19:21:14.000000Z
# 2019-10-16T17:12:54.000000Z
# 2019-10-16T15:38:03.000000Z
# 2019-10-16T15:10:36.000000Z
# 2019-10-16T00:19:46.000000Z
# 2019-10-15T15:36:28.000000Z
# 2019-10-15T14:24:12.000000Z
# 2019-10-14T13:00:23.000000Z
# 2019-10-13T16:37:48.000000Z
# 2019-10-13T14:47:36.000000Z
# 2019-10-12T16:14:58.000000Z
# 2019-10-12T13:10:00.000000Z
# 2019-10-11T11:11:44.000000Z
# 2019-10-10T15:36:10.000000Z
# 2019-10-10T15:11:34.000000Z
# 2019-10-10T10:52:05.000000Z
# 2019-10-09T15:41:29.000000Z
# 2019-10-09T09:57:21.000000Z
# 2019-10-07T15:00:47.000000Z
# 2019-10-06T18:20:23.000000Z
# 2019-10-06T17:29:58.000000Z
# 2019-10-06T11:52:18.000000Z
# 2019-10-05T12:44:18.000000Z
# 2019-10-05T08:45:01.000000Z
# 2019-10-04T17:30:58.000000Z
# 2019-10-04T07:30:14.000000Z
# 2019-10-03T17:08:59.000000Z
# 2019-10-03T10:54:08.000000Z
# 2019-10-03T09:53:37.000000Z
# 2019-10-03T09:27:11.000000Z
# 2019-10-03T08:13:05.000000Z
# 2019-10-02T08:00:16.000000Z
# 2019-10-01T14:53:43.000000Z
# 2019-10-01T07:14:39.000000Z
# 2019-09-30T06:28:12.000000Z
# 2019-09-29T13:09:49.000000Z
# 2019-09-29T10:09:48.000000Z
# 2019-09-29T06:40:25.000000Z
# 2019-09-28T06:45:47.000000Z
# 2019-09-28T05:24:58.000000Z
# 2019-09-28T03:54:28.000000Z
# 2019-09-27T15:01:16.000000Z
# 2019-09-27T12:59:30.000000Z
# 2019-09-26T06:11:18.000000Z
# 2019-09-25T13:22:13.000000Z
# 2019-09-25T06:28:01.000000Z
# 2019-09-25T03:59:23.000000Z
# 2019-09-23T03:39:02.000000Z
# 2019-09-23T01:39:46.000000Z
# 2019-09-23T01:00:00.000000Z
# 2019-09-22T05:37:58.000000Z
# 2019-09-22T03:42:26.000000Z
# 2019-09-22T03:02:02.000000Z
# 2019-09-21T06:08:29.000000Z
# 2019-09-21T03:15:42.448403Z
# 2019-09-21T02:02:30.000000Z
# 2019-09-20T00:42:29.000000Z
# 2019-09-19T23:56:34.000000Z
# 2019-08-27T11:06:26.000000Z
# 2019-08-27T10:27:58.000000Z
# 2019-08-27T09:38:37.000000Z
# 2019-08-27T07:31:53.000000Z
# 2019-08-26T10:23:58.000000Z
# 2019-08-26T09:34:51.000000Z
# 2019-08-26T07:59:24.000000Z
# 2019-08-26T06:48:36.000000Z
# 2019-08-26T05:30:16.000000Z
# 2019-08-25T10:27:57.000000Z
# 2019-08-25T08:24:46.000000Z
# 2019-08-25T07:17:59.000000Z
# 2019-08-25T06:16:22.000000Z
# 2019-08-24T15:43:49.000000Z
# 2019-08-24T07:02:53.000000Z
# 2019-08-24T06:06:50.000000Z
# 2019-08-23T11:07:18.000000Z
# 2019-08-23T08:38:15.000000Z
# 2019-08-22T07:01:20.000000Z
# 2019-08-22T05:19:38.000000Z
# 2019-08-21T07:09:54.000000Z
# 2019-08-21T05:05:57.000000Z
# 2019-08-18T03:30:04.000000Z
# 2019-08-18T01:01:07.000000Z
# 2019-08-18T00:16:57.000000Z
# 2019-08-17T05:00:13.000000Z
# 2019-08-17T02:20:35.000000Z
# 2019-08-16T09:50:07.000000Z
# 2019-08-16T03:53:41.000000Z
# 2019-08-16T00:30:05.000000Z
# 2019-08-15T03:06:01.000000Z
# 2019-08-15T02:39:20.000000Z
# 2019-08-15T00:02:56.000000Z
# 2019-08-14T00:16:23.000000Z
# 2019-08-13T23:33:39.000000Z
# 2019-08-12T23:45:53.000000Z
# 2019-08-12T21:14:27.000000Z
# 2019-08-11T23:06:24.000000Z
# 2019-08-11T20:57:27.000000Z
# 2019-08-11T20:30:13.000000Z
# 2019-08-11T00:14:20.000000Z
# 2019-08-10T21:00:37.000000Z
# 2019-08-09T21:31:29.000000Z
# 2019-08-09T01:46:09.000000Z
# 2019-08-08T21:49:52.000000Z
# 2019-08-08T21:20:02.000000Z
# 2019-08-08T04:00:43.000000Z
# 2019-08-07T21:58:10.000000Z
# 2019-08-07T21:41:47.000000Z
# 2019-08-06T20:53:44.000000Z
# 2019-08-06T18:15:53.000000Z
# 2019-08-04T20:44:53.000000Z
# 2019-08-04T19:11:45.000000Z
# 2019-08-04T18:02:08.000000Z
# 2019-08-04T17:41:10.000000Z
# 2019-08-04T16:56:44.000000Z
# 2019-08-02T17:43:22.000000Z
# 2019-08-02T16:02:00.000000Z
# 2019-08-02T15:15:16.000000Z
# 2019-08-01T21:42:55.000000Z
# 2019-08-01T18:42:46.000000Z
# 2019-08-01T15:00:32.000000Z
# 2019-07-31T14:45:05.000000Z
# 2019-07-30T19:31:24.000000Z
# 2019-07-30T14:13:18.000000Z
# 2019-07-29T12:50:12.000000Z
# 2019-07-28T14:11:03.000000Z
# 2019-07-27T13:44:54.000000Z
# 2019-07-27T10:46:01.000000Z
# 2019-07-26T15:05:00.000000Z
# 2019-07-26T12:52:10.000000Z
# 2019-07-26T12:16:15.587009Z
# 2019-07-26T10:43:56.000000Z
# 2019-07-25T14:09:59.000000Z
# 2019-07-25T12:53:37.000000Z
# 2019-07-25T12:28:10.000000Z
# 2019-07-25T10:16:21.000000Z
# 2019-07-24T11:40:32.000000Z
# 2019-07-22T08:09:45.000000Z
# 2019-07-22T07:25:23.000000Z
# 2019-07-20T08:46:52.000000Z
# 2019-07-19T09:36:34.000000Z
# 2019-07-19T07:16:33.000000Z
# 2019-07-19T05:35:58.000000Z
# 2019-07-18T08:41:45.000000Z
# 2019-07-18T07:48:10.000000Z
# 2019-07-18T06:52:57.000000Z
# 2019-07-18T06:04:20.000000Z
# 2019-07-17T06:37:20.000000Z
# 2019-07-17T05:36:45.000000Z
# 2019-07-17T04:32:55.000000Z
# 2019-07-16T06:18:05.000000Z
# 2019-07-13T03:30:12.000000Z
# 2019-07-12T03:41:20.000000Z
# 2019-07-12T03:07:34.000000Z
# 2019-07-11T08:00:00.000000Z
# 2019-07-10T03:19:32.000000Z
# 2019-07-10T02:21:29.000000Z
# 2019-07-10T00:18:44.000000Z
# 2019-07-09T04:58:25.000000Z
# 2019-07-08T00:25:07.000000Z
# 2019-07-07T00:35:28.000000Z
# 2019-07-06T23:51:24.000000Z
# 2019-07-06T09:55:17.000000Z
# 2019-07-05T23:39:52.000000Z
# 2019-07-05T23:10:18.000000Z
# 2019-07-03T19:43:14.000000Z
# 2019-07-03T06:43:59.000000Z
# 2019-07-02T19:13:00.000000Z
# 2019-07-02T07:32:56.000000Z
# 2019-07-02T06:29:26.000000Z
# 2019-07-02T03:46:07.000000Z
# 2019-07-01T21:39:19.000000Z
# 2019-07-01T19:45:37.000000Z
# 2019-07-01T18:47:35.000000Z
# 2019-06-30T17:30:47.000000Z
# 2019-06-26T15:33:54.000000Z
# 2019-06-25T17:10:10.000000Z
# 2019-06-25T14:50:37.000000Z
# 2019-06-23T23:30:56.000000Z
# 2019-06-23T17:11:40.000000Z
# 2019-06-23T15:00:00.000000Z
# 2019-06-23T13:07:11.000000Z
# 2019-06-22T15:46:19.000000Z
# 2019-06-22T14:00:03.000000Z
# 2019-06-22T12:40:56.000000Z
# 2019-06-22T01:17:09.000000Z
# 2019-06-21T15:12:18.000000Z
# 2019-06-21T12:52:03.000000Z
# 2019-06-21T12:05:45.000000Z
# 2019-06-20T14:56:41.000000Z
# 2019-06-20T11:40:35.000000Z
# 2019-06-18T10:11:14.000000Z
# 2019-06-17T12:10:54.000000Z
# 2019-06-17T09:32:08.000000Z
# 2019-06-16T08:46:36.000000Z
# 2019-06-15T08:11:11.000000Z
# 2019-06-14T12:32:51.000000Z
# 2019-06-14T10:29:37.000000Z
# 2019-06-14T08:07:37.000000Z
# 2019-06-14T07:31:21.000000Z
# 2019-06-13T07:02:05.000000Z
# 2019-06-12T05:51:57.000000Z
# 2019-06-11T07:03:46.000000Z
# 2019-06-10T04:31:10.000000Z
# 2019-06-09T05:37:50.000000Z
# 2019-06-06T03:30:19.000000Z
# 2019-06-05T11:00:00.000000Z
# 2019-06-05T03:25:46.000000Z
# 2019-06-05T02:06:23.000000Z
# 2019-06-03T03:54:19.000000Z
# 2019-06-03T02:27:46.000000Z
# 2019-06-02T02:00:00.000000Z
# 2019-05-23T02:19:33.612519Z
# 2019-05-21T18:54:03.000000Z
# 2019-05-18T18:00:00.000000Z
# 2019-05-17T19:29:13.000000Z
# 2019-05-17T16:39:32.000000Z
# 2019-05-04T07:01:03.000000Z
# 2019-05-02T07:19:49.000000Z
# 2019-05-01T03:03:36.000000Z
# 2019-04-12T18:12:51.000000Z
# 2019-04-11T13:27:22.663923Z
# 2019-04-07T09:31:52.000000Z
# 2019-03-26T06:20:00.000000Z
# 2019-03-14T20:59:38.000000Z
# 2019-01-13T05:53:29.000000Z
# <class 'obspy.core.utcdatetime.UTCDateTime'>

# %%
event_times = []

for event in catalog:
    times = event.origins[0].time
    event_times.append(times)

print(event_times)
print(type(event_times))   #event_times is a list
# Out:
# [UTCDateTime(2019, 12, 31, 17, 30), UTCDateTime(2019, 12, 30, 18, 22, 51), UTCDateTime(2019, 12, 30, 15, 46, 43), UTCDateTime(2019, 12, 29, 14, 36, 6), UTCDateTime(2019, 12, 28, 18, 2, 8), UTCDateTime(2019, 12, 28, 14, 52, 30), UTCDateTime(2019, 12, 27, 15, 6, 37), UTCDateTime(2019, 12, 27, 13, 50, 37), UTCDateTime(2019, 12, 27, 12, 37, 42), UTCDateTime(2019, 12, 26, 16, 38, 20), UTCDateTime(2019, 12, 26, 14, 45, 4), UTCDateTime(2019, 12, 26, 13, 4, 26), UTCDateTime(2019, 12, 26, 11, 49, 57), UTCDateTime(2019, 12, 25, 15, 43, 18), UTCDateTime(2019, 12, 25, 15, 22, 37), UTCDateTime(2019, 12, 25, 14, 32, 24), UTCDateTime(2019, 12, 24, 14, 31, 50), UTCDateTime(2019, 12, 23, 13, 49, 15), UTCDateTime(2019, 12, 23, 13, 30, 47), UTCDateTime(2019, 12, 23, 11, 45, 35), UTCDateTime(2019, 12, 23, 11, 6), UTCDateTime(2019, 12, 23, 10, 52, 43), UTCDateTime(2019, 12, 23, 9, 59, 27), UTCDateTime(2019, 12, 22, 15, 21, 55), UTCDateTime(2019, 12, 21, 13, 43, 26), UTCDateTime(2019, 12, 21, 12, 22, 36), UTCDateTime(2019, 12, 20, 13, 8, 30), UTCDateTime(2019, 12, 20, 7, 53, 37), UTCDateTime(2019, 12, 19, 11, 57, 20), UTCDateTime(2019, 12, 19, 10, 51, 9), UTCDateTime(2019, 12, 19, 10, 1, 16), UTCDateTime(2019, 12, 18, 11, 53, 30), UTCDateTime(2019, 12, 17, 16, 32, 22), UTCDateTime(2019, 12, 17, 10, 13, 55), UTCDateTime(2019, 12, 16, 11, 45, 12), UTCDateTime(2019, 12, 16, 10, 2, 2), UTCDateTime(2019, 12, 15, 10, 18, 13), UTCDateTime(2019, 12, 15, 7, 7, 31), UTCDateTime(2019, 12, 14, 7, 31, 54), UTCDateTime(2019, 12, 13, 8, 23, 51), UTCDateTime(2019, 12, 13, 6, 39, 8), UTCDateTime(2019, 12, 12, 3, 17, 29), UTCDateTime(2019, 12, 11, 8, 0, 23), UTCDateTime(2019, 12, 11, 3, 53, 2), UTCDateTime(2019, 12, 11, 1, 50, 49), UTCDateTime(2019, 12, 10, 7, 9, 3), UTCDateTime(2019, 12, 9, 4, 42, 9), UTCDateTime(2019, 12, 9, 3, 43), UTCDateTime(2019, 12, 9, 1, 42, 46), UTCDateTime(2019, 12, 9, 0, 31, 3), UTCDateTime(2019, 12, 8, 5, 36, 24), UTCDateTime(2019, 12, 8, 3, 32, 43), UTCDateTime(2019, 12, 8, 2, 33, 48), UTCDateTime(2019, 12, 8, 1, 45, 15), UTCDateTime(2019, 12, 8, 0, 24, 38), UTCDateTime(2019, 12, 7, 5, 59, 42), UTCDateTime(2019, 12, 7, 5, 28, 8), UTCDateTime(2019, 12, 7, 0, 49, 35), UTCDateTime(2019, 12, 6, 2, 50, 12), UTCDateTime(2019, 12, 5, 1, 33, 11), UTCDateTime(2019, 12, 5, 0, 48, 20), UTCDateTime(2019, 12, 5, 0, 8, 18), UTCDateTime(2019, 12, 4, 22, 53, 48), UTCDateTime(2019, 12, 4, 1, 13, 36), UTCDateTime(2019, 12, 3, 23, 30, 53), UTCDateTime(2019, 12, 3, 22, 6, 4), UTCDateTime(2019, 12, 3, 0, 40, 48), UTCDateTime(2019, 12, 2, 23, 8, 33), UTCDateTime(2019, 12, 2, 3, 22), UTCDateTime(2019, 12, 1, 23, 50, 56), UTCDateTime(2019, 12, 1, 20, 4, 41), UTCDateTime(2019, 11, 30, 21, 7, 10), UTCDateTime(2019, 11, 30, 0, 45, 44), UTCDateTime(2019, 11, 29, 22, 54, 1), UTCDateTime(2019, 11, 29, 21, 42, 52), UTCDateTime(2019, 11, 29, 0, 18, 4), UTCDateTime(2019, 11, 28, 19, 22), UTCDateTime(2019, 11, 26, 16, 42, 50), UTCDateTime(2019, 11, 25, 1, 21, 22), UTCDateTime(2019, 11, 24, 21, 57, 15), UTCDateTime(2019, 11, 24, 19, 58, 54), UTCDateTime(2019, 11, 24, 18, 49, 1), UTCDateTime(2019, 11, 24, 16, 35, 14), UTCDateTime(2019, 11, 24, 15, 4, 34), UTCDateTime(2019, 11, 24, 2, 21, 39), UTCDateTime(2019, 11, 23, 19, 27, 22), UTCDateTime(2019, 11, 23, 18, 14, 20), UTCDateTime(2019, 11, 22, 17, 40, 33), UTCDateTime(2019, 11, 21, 15, 58, 29), UTCDateTime(2019, 11, 20, 17, 9, 14), UTCDateTime(2019, 11, 19, 22, 51, 20), UTCDateTime(2019, 11, 19, 17, 44, 21), UTCDateTime(2019, 11, 19, 15, 45, 40), UTCDateTime(2019, 11, 19, 14, 48, 9), UTCDateTime(2019, 11, 19, 14, 0, 50), UTCDateTime(2019, 11, 18, 14, 47, 32), UTCDateTime(2019, 11, 17, 15, 25, 2), UTCDateTime(2019, 11, 17, 15, 11, 22), UTCDateTime(2019, 11, 17, 14, 25, 19), UTCDateTime(2019, 11, 17, 12, 25, 32), UTCDateTime(2019, 11, 16, 15, 35, 16), UTCDateTime(2019, 11, 16, 14, 42, 8), UTCDateTime(2019, 11, 16, 14, 0, 22), UTCDateTime(2019, 11, 16, 12, 3, 41), UTCDateTime(2019, 11, 15, 10, 1, 17), UTCDateTime(2019, 11,  ...
# <class 'list'>

# %%
#creating waveforms (times are already 3min ahead of energy start)
def cat_waveforms(start, adjtime):
    start_t = start - adjtime
    end_t = start + adjtime
    event_st = client.get_waveforms("XB", "ELYSE", "02", "B*", start_t, end_t)
    return event_st

# %%
first_5 = event_times[0:5]
print(first_5)

for time in first_5:
    data = cat_waveforms(time, 3*60)
    data.plot()
# Out:
# [UTCDateTime(2019, 12, 31, 17, 30), UTCDateTime(2019, 12, 30, 18, 22, 51), UTCDateTime(2019, 12, 30, 15, 46, 43), UTCDateTime(2019, 12, 29, 14, 36, 6), UTCDateTime(2019, 12, 28, 18, 2, 8)]
# <img src="data:image/png;base64,..." width="799.4444656224904">
# <img src="data:image/png;base64,..." width="799.4444656224904">
# <img src="data:image/png;base64,..." width="799.4444656224904">
# <img src="data:image/png;base64,..." width="799.4444656224904">
# <img src="data:image/png;base64,..." width="799.4444656224904">

# %%
f2 = open('marsquake_event.txt', 'w')

for time in first_5:
    str_time = str(time) + '\n'
    f2.write(str_time)

f2.close()

# %%
f = open('mars_hfevents.txt', 'w')

for time in event_times:
    str_time = str(time) + '\n'
    f.write(str_time)

f.close()

# %%
file = open('marsquake_event.txt', 'r')

from_file_times = []

for line in file:
    time = line.strip()
    UTCtime = UTCDateTime(time)
    from_file_times.append(UTCtime)
    
print(from_file_times)
print(type(from_file_times[0]))
# Out:
# [UTCDateTime(2019, 12, 31, 17, 30), UTCDateTime(2019, 12, 30, 18, 22, 51), UTCDateTime(2019, 12, 30, 15, 46, 43), UTCDateTime(2019, 12, 29, 14, 36, 6), UTCDateTime(2019, 12, 28, 18, 2, 8)]
# <class 'obspy.core.utcdatetime.UTCDateTime'>

# %%
for t in from_file_times:
    wave = cat_waveforms(t, 3*60)
    wave.plot()
# Out:
# <img src="data:image/png;base64,..." width="799.4444656224904">
# <img src="data:image/png;base64,..." width="799.4444656224904">
# <img src="data:image/png;base64,..." width="799.4444656224904">
# <img src="data:image/png;base64,..." width="799.4444656224904">
# <img src="data:image/png;base64,..." width="799.4444656224904">

# %%
fig1,ax = plt.subplots(3,2, figsize=(16,14))
plt.subplots_adjust(left=0.05, right=0.95, bottom=0.05, top=0.95, hspace=0.8)
# Out:
# <img src="data:image/png;base64,..." width="1599.4444868152536">

# %%
def waveform_filter(stream, event_type):
    
    stream.detrend('linear')
    stream.taper(max_percentage=0.05, type='cosine')
    
    if event_type == 'lf' or 'bb':
        filtered_stream1 = stream.filter('bandpass', freqmin = 0.125, freqmax = 0.5)
        return filtered_stream1
    elif event_type == 'hf':
        filtered_stream2 = stream.filter('highpass', freq = 1)
        return filtered_stream2
    elif event_type == '2.4':
        filtered_stream3 = stream.filter('bandpass', freqmin = 1, freqmax = 4)
        return filtered_stream3
    elif event_type == 'shf':
        filtered_stream4 = stream.filter('bandpass', freqmin = 8, freqmax = 15)
        return filtered_stream4
    elif event_type == 'vhf':
        filtered_stream5 = stream.filter('bandpass', freqmin == 5, freqmax = 10)
        return filtered_stream5
    else:
        text = "This isn't a valid event type"
        return text

def waveform_plotter(date, filtered, ax, ylim = False, channels = [0,1,2]):
    
    for channel in channels:
        full_code = filtered[channel].id
        code = full_code[12:]
        offset = channel * np.full(len(filtered[channel]), fill_value=200) 
        
        tr = filtered[channel]
        t = tr.times('matplotlib')
        
        if code == 'BHU':
            ax.plot(t, filtered[channel].data + offset, label=code, color = "#1f77b4", alpha = 0.7)
        elif code == 'BHV':
            ax.plot(t, filtered[channel].data + offset, label=code, color = "#ff7f0e", alpha = 0.7)
        elif code == 'BHW':
            ax.plot(t, filtered[channel].data + offset, label=code, color = "#2ca02c", alpha = 0.7)
        else:
            ax.plot(t, filtered[channel].data + offset, label="Unknown " + code, color = "black", alpha = 0.7)
    
    ax.xaxis_date()
    x_labels = ax.get_xticklabels()
    ax.set_xticklabels(x_labels, rotation=30, ha='right', va='center_baseline', size=9)
    ax.xaxis.set_major_formatter(DateFormatter('%H:%M:%S'))
    ax.xaxis.set_major_locator(ticker.MaxNLocator(8))
    
    ax.axvline(pd.to_datetime(date), c='r', ls='--', alpha = 0.5)
    
    if ylim == True:
        ax.set_ylim(-800,1000)

k = 0
for num in range(0,3):
    for numb in range(0,2):
        if k < len(from_file_times):
            t = from_file_times[k]
            try:
                wave = cat_waveforms(t, 3*60)
                filt = waveform_filter(wave, 'hf')
                waveform_plotter(str(t), filt, ax[num,numb])
                print(num, numb, t, k)
            except:
                print('Error occured', t)
            k += 1
# Out:
# 0 0 2019-12-31T17:30:00.000000Z 0
# 0 1 2019-12-30T18:22:51.000000Z 1
# 1 0 2019-12-30T15:46:43.000000Z 2
# 1 1 2019-12-29T14:36:06.000000Z 3
# 2 0 2019-12-28T18:02:08.000000Z 4
